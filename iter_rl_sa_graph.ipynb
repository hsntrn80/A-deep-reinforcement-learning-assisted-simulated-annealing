# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('results/out.csv', header=None)
df.head()
plt.figure(figsize=(20,20))
start = 338400
iters_to_plot = 3500
plt.scatter(df[0][start:start+iters_to_plot], df[3][start:start+iters_to_plot], label="RL")
plt.scatter(df[0][start:start+iters_to_plot], df[4][start:start+iters_to_plot], label ="SA")
plt.xlabel('Iteration')
plt.ylabel('Min Cost')
plt.legend()
plt.show()
